# %%
import random
import pandas as pd
import numpy as np

# %%
# Create lists of random data
loan_amount = [random.randint(100000, 500000) for i in range(1000)]
credit_score = [random.randint(500, 850) for i in range(1000)]
property_value = [random.randint(200000, 700000) for i in range(1000)]
loan_to_value = [random.uniform(0.5, 1.0) for i in range(1000)]
loan_term = [random.choice([15, 20, 25, 30, 40]) for i in range(1000)]
employment_length = [random.choice(['< 1 year', '1-3 years', '3-5 years', '5-10 years', '10+ years']) for i in range(1000)]
location = [random.choice(['Urban', 'Suburban', 'Rural']) for i in range(1000)]
loan_type = [random.choice(['Fixed', 'Adjustable']) for i in range(1000)]
property_type = [random.choice(['Single Family', 'Multi Family', 'Condo', 'Townhouse']) for i in range(1000)]
state = [random.choice(['CA', 'NY', 'TX', 'FL', 'IL', 'PA', 'OH', 'GA', 'NC', 'MI']) for i in range(1000)]
debt_to_income_dti= [random.randint(10, 50) for i in range(1000)]
down_payment= [random.randint(10000, 100000) for i in range(1000)]
income= [random.randint(100000, 350000) for i in range(1000)]
occupancy_type= [random.choice(['Primary', 'Secondary', 'Investment']) for i in range(1000)]

# %%
# Calculate interest rates
interest_rate = [round(random.uniform(2.5, 5.5) + (credit_score[i]/100) - (loan_to_value[i]*0.5) - (loan_term[i]*0.1), 2) for i in range(1000)]

# %%
# Create a dictionary of the data
data = {'Loan Amount': loan_amount,
        'Credit Score': credit_score,
        'Property Value': property_value,
        'Loan-to-Value Ratio': loan_to_value,
        'Loan Term (years)': loan_term,
        'Employment Length': employment_length,
        'Location': location,
        'Loan Type': loan_type,
        'Property Type': property_type,
        'State': state,
        'Interest Rate': interest_rate,
        'Debt-To-Income DTI':debt_to_income_dti,
        'Down Payment $': down_payment,
        'Income': income,
        'Ocuppancy Type': occupancy_type
       }
# Convert dictionary to a dataframe
df = pd.DataFrame(data)
# Print the first 10 rows of the dataframe
df.head(10)
# Out:
#    Loan Amount  Credit Score  Property Value  Loan-to-Value Ratio  \
# 0       125097           592          298222             0.734713
# 1       438270           785          460351             0.650979
# 2       492566           751          454822             0.663986
# 3       154274           570          380628             0.655645
# 4       282765           824          335052             0.978570
# 5       488710           681          608498             0.590631
# 6       437494           517          210943             0.623199
# 7       402055           831          366521             0.797541
# 8       389635           799          463121             0.570517
# 9       349245           697          653771             0.685546
#
#    Loan Term (years) Employment Length  Location   Loan Type  Property Type  \
# 0                 20         1-3 years  Suburban       Fixed          Condo
# 1                 20        5-10 years     Urban       Fixed  Single Family
# 2                 40         3-5 years  Suburban  Adjustable          Condo
# 3                 25        5-10 years     Rural  Adjustable          Condo
# 4                 30         10+ years     Rural       Fixed   Multi Family
# 5                 20         1-3 years  Suburban  Adjustable          Condo
# 6                 25         3-5 years  Suburban  Adjustable  Single Family
# 7                 15         3-5 years     Rural  Adjustable      Townhouse
# 8                 40        5-10 years     Rural       Fixed      Townhouse
# 9                 40         1-3 years     Rural       Fixed      Townhouse
#
#   State  Interest Rate  Debt-To-Income DTI  Down Payment $  Income  \
# 0    NY           9.05                  33           26275  227793
# 1    NY           9.59                  22           29148  195605
# 2    TX           6.29                  50           86821  252967
# 3    MI           6.03                  45           87797  217503
# 4    IL           7.48                  18           21651  109696
# 5    FL           9.70                  18           14301  287123
# 6    TX           6.00                  49           63298  276260
# 7    NC          10.77                  13           25493  129481
# 8    FL           7.83                  41           31436  103118
# 9    NC           7.98                  50           81373  105832
#
#   Ocuppancy Type
# 0      Secondary
# 1        Primary
# 2      Secondary
# 3        Primary
# 4     Investment
# 5      Secondary
# 6        Primary
# 7        Primary
# 8      Secondary
# 9        Primary

# %%
# Exporting the dataframe to a CSV file
df.to_csv('mortgage_interest_rates_gpt.csv', index=False)
